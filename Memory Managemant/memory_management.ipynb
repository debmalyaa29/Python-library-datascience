# %%
import gc
##enable garbage collector
gc.enable()

# %%
gc.collect()
# Out:
# 41

# %%
##Get garbage collection stata
print(gc.get_stats())
# Out:
# [{'collections': 177, 'collected': 1435, 'uncollectable': 0}, {'collections': 15, 'collected': 349, 'uncollectable': 0}, {'collections': 2, 'collected': 62, 'uncollectable': 0}]

# %%
##Handling circular refewrence
import gc

class MyObject:
    def __init__(self,name):
        self.name=name
        print(f"Object {self.name} created")

    def __del__(self):
        print(f"Object {self.name} deleted")    

##Craeate circular reference
obj1=MyObject("obj1")
obj2=MyObject("Obj2")
obj1.ref=obj2
obj2.ref=obj1

del obj1
del obj2
##Manually trigger the garbage collection
gc.collect()
gc.get_count()
# Out:
# Object obj1 created
# Object Obj2 created
# Object obj1 deleted
# Object Obj2 deleted
# (28, 0, 0)

# %%
##Generators for Memory Effiency
###generator alollows you to create one item at a time,using memory efficiently by only keeping one item in memory at a time
def generate_numbers(n):
    for i in range(n + 1):
        yield i


gen = generate_numbers(5)

for num in gen:
    print(num)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
###Profiling Memory Usage with tracemalloc
